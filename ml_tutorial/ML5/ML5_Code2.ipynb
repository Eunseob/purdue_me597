# %% [markdown]
# ## Import Packages

# %%
# Import Numpy and Pandas packages

# %%
# Acess to your google drive

# %% [markdown]
# ## Load the SELECTED (Top 30) Feature Dataset
# * Results of ML3-1 and ML3-2

# %%
FeatureSelected = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SavedFiles/FeatureSelected.csv', header=None)
FeatureSelected = FeatureSelected.T
FeatureSelected.shape

# %%
# Standardize feature values

# %% [markdown]
# ## Split Training & Test Data
# - Use 'train_test_split' function
# - It randomly samples the training and testing data according to the designated ratio.

# %% [markdown]
# ## Data Labling
# - Use 'np.zeros' and 'np.ones'
# - '0' refers to 'Normal' and '1' refers to 'Abnormal' in this tutorial

# %%
 # 0: Normal
 # 1: Abnormal
 # 0: Normal
 # 1: Abnormal

# %% [markdown]
# ## Data and Label Preparation

# %%
TrainData  = 
TestData   = 
TrainLabel = 
TestLabel  = 

print(TrainData.shape,  TestData.shape)
print(TrainLabel.shape, TestLabel.shape)

# Shape of TraninData and TrainLabel should be: (288, 30) (288,)
# Shape of TestData   and TestLabel  should be: (72, 30)  (72,)

# %% [markdown]
# ## K-Nearest Neighbor (KNN) Model Training

# %%
from sklearn.neighbors import KNeighborsClassifier as knn

knnModel = knn(         ) # set a hyperparameter of KNN 'n_neighbor' as 3
knnModel.fit(           ) # Train KNN model with TrainData and TrainLabel


Predicted =               # Get the predicted result for test data
Predicted

# %% [markdown]
# Performance (Accuracy) Test Result

# %%
# Calculate accuracy by comparing the predicted result and label
svmscore = knnModel.score(TestData, TestLabel)

print("Accuracy of KNN model trained by top30 features:\n{}%".format(svmscore*100))

# %% [markdown]
# Save ML model (KNN) as a file

# %%
# Save the trainded KNN model in your Drive ('Colab Notebooks/SavedFiles/ML_Models/')

# %% [markdown]
# Load the saved ML model (KNN) and predict

# %%
# Load the saved KNN model and output the predicted result of test data using it
