# %% [markdown]
# # ML Homework 3 Guide

# %% [markdown]
# 1. Save a copy of this ipynb file in your GoogleDrive or PC.
# 2. Edit the name of this code from "HW3.ipynb" to "HW3_(your name).ipynb"
# 3. Fill out the code cells below according to descriptions.
# 4. Save and upload to BrightSpace. (DO NOT clear the outputs of your code)
# 5. Convert the .ipynb file to PDF file and upload together

# %% [markdown]
# # [HW 3] Customize ANN
#
# Design and train a customized ANN model according to the following instructions:
#
# 1. Set the learning rate to 0.01.
# 2. Set the number of hidden layers to 3.
# 3. Set the number of neurons in the first hidden layer to 15.
# 4. Set the number of neurons in the second hidden layer to 10.
# 5. Set the number of neurons in the third hidden layer to 5.
# 6. Set the number of training epochs to 300.
# 7. Set the activation function differently from the ML6 code by referring to the link provided in the code.
# 8. Set the loss function and optimization algorithm differently from the ML6 code by referring to the link provided.
#
#
# * Use dataset resulted from ML3_Code2 (FeatureSelected)
#
# * Plot a graph of the training process (Loss, Accuracy) at the end
#
# * Refer to ML6_Code1

# %%
# Start with importing packages




































# Check the training process (Loss, Accuracy)

# %% [markdown]
# ## ML5 and ML6 Summary and Deliverables
#
# Answer the following questions for your achievements

# %% [markdown]
# ### Q1. Please summarize ML5 and ML6.
#
# ---
#
# Write down A1 here.
#
# ---

# %% [markdown]
# ### Q2. What skills did you have to develop to accomplish this project?
#
# ---
#
# Wirte down A2 here.
#
# ---

# %% [markdown]
# ### Q3. What aspects of this project were the most beneficial for your learning?
#
# ---
#
# Wirte down A3 here.
#
# ---

# %% [markdown]
# ### Q4. What challenges did you encounter in completing the project?
#
# ---
#
# Wirte down A4 here.
#
# ---

# %% [markdown]
# ### Q5. How did you overcome the challenges or remedy the problems encountered?
#
# ---
#
# Wirte down A5 here.
#
# ---
