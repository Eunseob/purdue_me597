# %% [markdown]
# <a href="https://githubtocolab.com/Eunseob/purdue_me597/blob/main/lab/lab7/PL7_Colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prelab 7.1 Database & Visualization 2 - Grafana dashboard

# %% [markdown]
# ## Learning Goals
#
# Students will be able to:
#
# 1. Identify the core components and features of the Grafana Dashboard
# 2. Analyze SQL statements and data formats
# 3. Write Python and SQL script to solve data manipulation functions

# %% [markdown]
# ## 1.1 Introduction
#
#
# In this lab, we will use a web visualization application, Grafana. Grafana is an open-source interactive visualization web dashboard application. Grafana provides various visualization functionalities, such as charts, tables, time series graphs, statistics, and alerts for the web according to the supported data sources. As data sources, Grafana supports both SQL and NoSQL. Grafana allows you to query, visualize, alert on, and understand your metrics no matter where you are stored. It enables to create, explore, and share dashboards. Major features of Grafana are as follows<sup>1</sup>.
#
# * Visualization
#   * Fast and flexible client-side graphs with a multitude of options. Panel plugins offer many ways to visualize metrics and logs
# * Dynamic Dashboards
#   * Create dynamic & reusable dashboards with template variables that appear as dropdown at the top of the dashboard.
#
# * Explore Metrics
#   * Explore your data through ad-hoc queries and dynamic drilldown. Split view and compare different time ranges, queries and data sources side by side.
# * Explore Logs
#   * Experience the magic of switching from metrics to logs with preserved label filters. Quickly search through all your logs or streaming them live.
# * Alerting
#   * Visually define alert rules for your most important metrics. Grafana will continuously evaluate and send notifications to systems like Slack, PagerDuty, VictorOps, OpsGenie.
# * Mixed Data Sources
#   * Mix different data sources in the same graph! You can specify a data source on a per-query basis. This works for even custom data sources.
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/prelab7_fig1.png?raw=true" width="100%">
#
#   *Figure 1 Example of web dashboard using Grafana for CNC machine and MTConnect*
#
# * Grafana official website: https://grafana.com/
#
# * Grafana Live Demo: https://play.grafana.org/d/000000012/grafana-play-home?orgId=1 (available on Feb. 7, 2023)
#
# ---
# <sup>1</sup>Grafana GitHub: https://github.com/grafana/grafana

# %% [markdown]
# ## 1.2 Preparation for Visualization
#
# In Lab7, we will visualize the stored data in MySQL database using Grafana so that you see graphs and charts in the web browser. In addition, we will create the entire data collection and visualization data stream from the sensor, edge computer, MTConnect, and database eventually to Grafana web dashboard as shown in Figure 2. This system allows us of enabling remote web-based and real-time monitoring as an application of IIoT implementation.
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/prelab7_fig2.png?raw=true" width="80%">
#
# *Figure 2 Schematic of remote real-time monitoring*
#
# To visualize data from MySQL to Grafana, you need to be familiar with SQL datatype and queries, especially “SELECT” statement. As a practice, perform Task 1.1.
# <br></br>
# *Table 1 Example of MySQL table*
#
# <table width="510">
# <tbody>
# <tr>
# <td width="40">
# <p>id</p>
# </td>
# <td width="152">
# <p>timestamp</p>
# </td>
# <td width="97">
# <p>sensor</p>
# </td>
# <td width="102">
# <p>measurement</p>
# </td>
# <td width="120">
# <p>value</p>
# </td>
# </tr>
# <tr>
# <td width="40">
# <p>&nbsp;</p>
# </td>
# <td width="152">
# <p>&nbsp;</p>
# </td>
# <td width="97">
# <p>&hellip;</p>
# </td>
# <td width="102">
# <p>&nbsp;</p>
# </td>
# <td width="120">
# <p>&nbsp;</p>
# </td>
# </tr>
# <tr>
# <td width="40">
# <p>5</p>
# </td>
# <td width="152">
# <p>2022-03-07 01:15:26</p>
# </td>
# <td width="97">
# <p>ADXL345</p>
# </td>
# <p>17</p>
# </td>
# <td width="152">
# <p>2022-03-07 01:15:28</p>
# </td>
# <td width="97">
# <p>ADXL345</p>
# </td>
# <td width="102">
# <p>Xacc</p>
# </td>
# <td width="120">
# <p>-0.04791</p>
# </td>
# </tr>
# <tr>
# <td width="40">
# <p>18</p>
# </td>
# <td width="152">
# <p>2022-03-07 01:15:28</p>
# </td>
# <td width="97">
# <p>ADXL345</p>
# </td>
# <td width="102">
# <p>Yacc</p>
# </td>
# <td width="120">
# <p>-0.00784</p>
# </td>
# </tr>
# <tr>
# <td width="40">
# <p>19</p>
# </td>
# <td width="152">
# <p>2022-03-07 01:15:28</p>
# </td>
# <td width="97">
# <p>ADXL345</p>
# </td>
# <td width="102">
# <p>Zacc</p>
# </td>
# <td width="120">
# <p>9.890663</p>
# </td>
# </tr>
# <tr>
# <td width="40">
# <p>&nbsp;</p>
# </td>
# <td width="152">
# <p>&nbsp;</p>
# </td>
# <td width="97">
# <p>&hellip;</p>
# </td>
# <td width="102">
# <p>&nbsp;</p>
# </td>
# <td width="120">
# <p>&nbsp;</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/prelab7_fig3.png?raw=true" width="80%">
#
# *Figure 3 Example of data: Z-axis acceleration (left) and Temperature (right)*

# %% [markdown]
# ### Task 1.1 SELECT Query Questions

# %%
#@title 1) What are SELECT statements to plot two time-series graphs like Figure 3 if your database table looks like Table 1? Write down two entire SELECT statements.  {display-mode: "form"}
#@markdown * Assume that your table name is 'ME597Spring22.yourname'.
#@markdown * Write down each full SELECT statement, e.g., SELECT SOMETHING


T1_Statement1 = '' #@param {type:"string"}
print(T1_Statement1)
T1_Statement2 = '' #@param {type:"string"}
print(T1_Statement2)

# %%
#@title 2) What are the result grids of each SELECT statement from the example table?  {display-mode: "form"}
#@markdown * For example, column 1 is A and column 2 is B.

T1_1 = '' #@param {type:"string"}
print(T1_2)
T1_2 = '' #@param {type:"string"}
print(T1_2)

# %% [markdown]
# ### Task 1.2 TIMESTAMP of MySQL

# %%
#@title 1) What is the format of 'TIMESTAMP' datatype of MySQL? {display-mode: "form"}
T2_1 = '' #@param {type:"string"}
print(T2_1)

# %% [markdown]
# ### Task 1.3 MTConnect timestamp
#
# An example of MTConnect timestamp is "2022-02-25T04:34:33.605220Z". Write down a Python script for which you want to convert the timestamp string of MTConnect to MySQL TIMESTAMP format. Attach your script to the report.
# * Both MTConnect timestamp and MySQL TIMESTAMP data types of Python are string.
# * Convert the MTConnect timestamp string given in this task to the timestamp string as MySQL TIMESTAMP format.
# * If needed, you need to convert the time zone.

# %%
# Insert your script here:
#



#

# %% [markdown]
# ## Further Instruction
#
# Grafana provides an extensive (1-hour) webinar about the Grafana 8 dashboard. Please watch the video so that you understand what Grafana is and how it works.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('0n2UNzk2OaI')
#Watch this video.

# %% [markdown]
# ### Task 1.4
#
# Model the process of a script that would collect all data from an MTConnect agent and send it to a MySQL database continuously by creating a flow diagram that illustrates the logic, sequence, and processes of the this script.
#
# ---
#
# Place URL here
#
# ---

# %% [markdown]
# <br></br>
#
# Get back to [Lab Index Page](https://colab.research.google.com/github/Eunseob/purdue_me597/blob/main/index.ipynb)
