# %% [markdown]
# # Lab 1 Edge Computer and Headless Environment Setup (Supplementary)

# %% [markdown]
# ### [Supplementary] Raspberry Pi Desktop setup with I/O interfaces
#
# If you have I/O (input/output) interfaces (monitor, keyboard, and mouse) and want to set up with GUI, Perform this section. But it is recommended to set up without the I/O interfaces to get familiar with headless system and CLI. **Skip this section and Go to 3.1.3 Raspberry Pi Desktop setup with an ethernet cable.**
# <br></br>
# Connect your Raspberry Pi to a monitor with an HDMI cable, keyboard, and mouse, and plug in your Raspberry Pi to turn it on (there is no "on" button). The Raspberry Pi should begin to boot up. **If you don't see anything happening (no signal on the monitor), then you may need to start troubleshooting steps. Please find troubleshooting at the end of this notebook.**
#
# Once the Raspberry Pi is working and you can use it with your keyboard and mouse, do basic setup such as ‘Country’, ‘Language’, ‘Timezone’, ‘Password’ and so on. If you are having trouble with setting up, please follow the Beginners Guide to Installing Raspberry Pi OS (https://medium.com/@mkmety/beginners-guide-to-installing-raspberry-pi-os-on-araspberry-pi-6d437ce2f54b, available on Jan. 11, 2023). After rebooting Raspberry Pi, you will see the screen like Figure 7. Task bar icons are described in Figure 8.
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/prelab0_fig9.png?raw=true" width="90%">
#
# *Figure 7 Main screen of Raspberry Pi Desktop*
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/prelab0_fig10.png?raw=true" width="50%">
#
# *Figure 8 Task bar icon*

# %% [markdown]
# ### Troubleshooting (optional)
#
# If you see "No Signal" on your monitor when you set up using GUI, a few things may be the cause. Below will detail,
# 1. The operating system is not installed correctly and therefore cannot display anything on the monitor
# 2. The Pi is not *able* to output anything to the monitor because of incompatible technology. But, we can change this.
#
# We will begin to troubleshoot possibility 2.
#
# Insert the SD card (with the OS installed) into your laptop. If you open the SD card in your file system, you will see a "config.txt" file. Open this "config.txt" file with a text editor, such as Notepad or Notepad++, then add the following line at the bottom of the file.
#
# `hdmi_safe=1`
#
# Save the file, close it, and eject the SD card from your laptop. Insert it back into your Raspberry Pi and see if the monitor now displays image.
#
# If this does not fix your issue, you can troubleshoot with help from this guide: https://elinux.org/R-Pi_Troubleshooting (available Jun 8. 2022).
