# %% [markdown]
# #Lab 1.1 IoT Sensor Data Collection 1 - Humidity and Temperature Sensor

# %% [markdown]
# ##Learning Goals
#
#
# *   Students will be able to code in Python to read data from the DHT11 sensor.
# * Students will be able to code in Python to save sensory data in a csv file.
# * Students will be able to plot sensory data in a line chart.

# %% [markdown]
# ## 1.1 Introduction
#
# In Lab1, we will measure atmospheric temperature and humidity from DHT11. Each DHT11 is already calibrated in the laboratory which is accurate on humidity and temperature calibration. Because the calibration coefficients are stored in the OTP (One-Time Programmable) memory of the sensor, we do not need to calibrate the sensor. The single-wire serial interface makes system integration quick and easy. Typical application and wiring diagram of DHT11 is shown in Figure 1. Technical specifications are shown in Table 1 and Table 2.
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/lab1_fig1.png?raw=true" width='70%'>
#
# *Figure 1 Wiring diagram of DHT11 and application (MCU: Micro-computer unit)*
#
# *Table 1 Overview of sensor specification*
#
# <table width="673">
# <tbody>
# <tr>
# <td width="86">
# <p>Sensor</p>
# </td>
# <td width="111">
# <p>Measurement</p>
# </td>
# <td width="104">
# <p>range</p>
# </td>
# <td width="77">
# <p>Accuracy</p>
# </td>
# <td width="100">
# <p>Refresh rate</p>
# </td>
# <td width="103">
# <p>Resolution</p>
# </td>
# <td width="120">
# <p>Package</p>
# </td>
# </tr>
# <tr>
# <td rowspan="2" width="86">
# <p>DHT11</p>
# </td>
# <td width="111">
# <p>Humidity</p>
# </td>
# <td width="104">
# <p>20-90%RH</p>
# </td>
# <td width="77">
# <p>&plusmn;5%RH</p>
# </td>
# <td rowspan="2" width="100">
# <p>2 seconds</p>
# </td>
# <td rowspan="2" width="103">
# <p>1</p>
# </td>
# <td rowspan="2" width="120">
# <p>4 Pin single row</p>
# </td>
# </tr>
# <tr>
# <td width="111">
# <p>Temperature</p>
# </td>
# <td width="104">
# <p>0-50&deg;C</p>
# </td>
# <td width="77">
# <p>&plusmn;2&deg;C</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
#
# *Table 2 Detailed Specifications*
#
# <table width="672">
# <tbody>
# <tr>
# <td width="102">
# <p>Measurement</p>
# </td>
# <td width="136">
# <p>Parameter</p>
# </td>
# <td width="109">
# <p>Conditions</p>
# </td>
# <td width="108">
# <p>Minimum</p>
# </td>
# <td width="108">
# <p>Typical</p>
# </td>
# <td width="109">
# <p>Maximum</p>
# </td>
# </tr>
# <tr>
# <td rowspan="9" width="102">
# <p>Humidity</p>
# </td>
# <td width="136">
# <p>Resolution</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>1%RH (8bit)</p>
# </td>
# <td width="108">
# <p>1%RH (8bit)</p>
# </td>
# <td width="109">
# <p>1%RH (8bit)</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Repeatability</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&plusmn;1%RH</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Accuracy</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&plusmn;4%RH</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# </tr>
# <tr>
# <td rowspan="3" width="136">
# <p>Range</p>
# </td>
# <td width="109">
# <p>0&deg;C</p>
# </td>
# <td width="108">
# <p>30%RH</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="109">
# <p>90%RH</p>
# </td>
# </tr>
# <tr>
# <td width="109">
# <p>25&deg;C</p>
# </td>
# <td width="108">
# <p>20%RH</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="109">
# <p>90%RH</p>
# </td>
# </tr>
# <tr>
# <td width="109">
# <p>50&deg;C</p>
# </td>
# <td width="108">
# <p>20%RH</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="109">
# <p>80%RH</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Response time</p>
# </td>
# <td width="109">
# <p>1/e (63%), 25&deg;C</p>
# </td>
# <td width="108">
# <p>6 seconds</p>
# </td>
# <td width="108">
# <p>10 seconds</p>
# </td>
# <td width="109">
# <p>15 seconds</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Hysteresis</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&plusmn;1%RH</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Long-term stability</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# </tr>
# <tr>
# <td rowspan="5" width="102">
# <p>Temperature</p>
# </td>
# <td width="136">
# <p>Resolution</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>1&deg;C (8bit)</p>
# </td>
# <td width="108">
# <p>1&deg;C (8bit)</p>
# </td>
# <td width="109">
# <p>1&deg;C (8bit)</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Repeatability</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&plusmn;1&deg;C</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Accuracy</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>&plusmn;1&deg;C</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="109">
# <p>&plusmn;2&deg;C</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Range</p>
# </td>
# <td width="109">
# <p>&nbsp;</p>
# </td>
# <td width="108">
# <p>0&deg;C</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="109">
# <p>50&deg;C</p>
# </td>
# </tr>
# <tr>
# <td width="136">
# <p>Response time</p>
# </td>
# <td width="109">
# <p>1/e (63%</p>
# </td>
# <td width="108">
# <p>6 seconds</p>
# </td>
# <td width="108">
# <p>&nbsp;</p>
# </td>
# <td width="109">
# <p>30 seconds</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
#
# To make a connection between DHT11 and Raspberry Pi, we will use GIPO (General-Purpose Input/Output) pins. The raw of GPIO pins is on powerful feature of the Raspberry Pi that allows us to make connection between Raspberry Pi and outside world. GPIO pins and number is shown in Figure 2 (Source:
# https://learn.sparkfun.com/tutorials/introduction-to-the-raspberry-pi-gpio-and-physical-computing/gpio-pinsoverview, available on Jan. 20, 2023). In lab manuals, pin wiring connection is described using pin number. For example, Pin 16 of Raspberry Pi means GPIO 23.
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/lab1_fig2.png?raw=true" width="100%">
#
# *Figure 2 Raspberry Pi (left) and GPIO pins with numbers (right)*
#
# In ‘Terminal’ you can see pin information as well. Using ‘pinout’ command, you can check basic information, board layout, GPIO pin information, and so on. Try the command below.
#
# ---
# **Raspberry Pi - Terminal**
#
# `pinout`
#
# ---
#
# Using GPIO pin connection and Python programming, in this lab, you will measure the atmospheric temperature and humidity of DHT11. Furthermore, you will save the collected data in a CSV file and plot to see the measured data.

# %% [markdown]
# ## 1.2 Wiring Connection
#
# Pin information of DHT11 is shown in Figure 3. Because the sensor Pin 3 is null, the pinout of the module does not have Pin 3. Using jumper wires given, make connection as Table 3.
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/lab1_fig3.png?raw=true" width="50%">
#
# *Figure 3 DHT11 and pin information*
#
# *Table 3 Pin wiring connection between DHT11 and Raspberry Pi*
#
# <table width="365">
# <tbody>
# <tr>
# <td width="183">
# <p>DHT11</p>
# </td>
# <td width="182">
# <p>Raspberry Pi</p>
# </td>
# </tr>
# <tr>
# <td width="183">
# <p>Pin 1 (Vcc, +)</p>
# </td>
# <td width="182">
# <p>Pin 1 (3.3V power*)</p>
# </td>
# </tr>
# <tr>
# <td width="183">
# <p>Pin 2 (Data, out)</p>
# </td>
# <td width="182">
# <p>Pin 16 (GPIO 23)</p>
# </td>
# </tr>
# <tr>
# <td width="183">
# <p>Pin 4 (GND, -)</p>
# </td>
# <td width="182">
# <p>Pin 6 (GND*)</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
#
#
# If you are already using a Pin, as Pin1 or Pin 6 of Raspberry Pi for any reasons, you can use alternatives. If alternatives are available, it is marked with * (asterisk mark). For example, Pin 17 (3.3V power) of Raspberry Pi is the same of Pin 1. Therefore, you can use Pin 17 instead of Pin 1 and Pin 9, 14, 20, 25, 34, or 39 instead of Pin 6. See the GPIO pins (Figure 2). Wiring diagram and configuration are shown in Figure 4 and Figure 5.
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/lab1_fig4.png?raw=true" width="70%">
#
# *Figure 4 Wiring diagram for DHT11*
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/lab1_fig5.png?raw=true" width="70%">
#
# *Figure 5 Wiring configuration for DHT11*

# %% [markdown]
# ### Task 1.1
#
# Take a picture of your wiring configuration as Figure 5 and attach it below:

# %% [markdown]
# ---
#
# Place your screenshot in here.
#
# ---

# %% [markdown]
# Now, we are ready to read data from DHT11.

# %% [markdown]
# ## 1.3 Reading Data from DHT 11 (Python)
#
# To read data, we will use Python packages installed in Prelab 1. If you are interested in detail how to measure DHT11 sensor value, see the manual attached on [here](https://github.com/Eunseob/purdue_me597/blob/main/lab/lab1/DHT11-Manual.pdf) and visit Adafruit webpage
# (https://learn.adafruit.com/dht-humidity-sensing-on-raspberry-pi-with-gdocs-logging/python-setup, available on Jan. 20, 2023). Create a Python script (e.g., DHT11.py) on Raspberry Pi, and then copy and paste the code below and run it. The data type of each measurement is an integer.
#
# * Comments are described after # (pound-sign) in the code.
#
# ---
# **Python - Python 3 (DHT11_sample.py)**
#
# ```
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
#
# import board
# import adafruit_dht
# import psutil
#
# # Kill libgpio process, if already used.
# for p in psutil.process_iter():
#   if p.name() == 'libgpiod_pulsei' or p.name() == 'libgpiod_pulsein':
#     p.kill()
#
# sensor = adafruit_dht.DHT11(board.D23) #sensor object for DHT11 sensor, D23 means Pin23 of Raspberry Pi
#
# temperature = sensor.temperature # temperature instance
# humidity = sensor.humidity # humidity instance
#
# print("Temperature:{}°C, Humidity:{}%RH".format(temperature, humidity))
# ```
#
# ---
#
# <img src="https://github.com/Eunseob/purdue_me597/blob/main/lab/img/lab1_fig6.png?raw=true" width="70%">
#
# *Figure 6 Terminal window after running sample code for DHT11*

# %% [markdown]
# You may need to handle any error that can occur. ‘try’ and ‘except’ functions of Python may help. Search try and except on the Internet if you are a beginner in Python.
#
# An example code of exception in while loop to prevent your program from being halted (for Task3) here: [dht_hint_exception.py](https://github.com/Eunseob/purdue_me597/blob/main/lab/lab1/dht11_hint_exception.py)

# %% [markdown]
# ### Task 1.2
#
# Capture the terminal window after running sample code and attach it to the report below:

# %% [markdown]
# ---
#
# Place your screenshot in here.
#
# ---

# %% [markdown]
# ### Task 1.3
#
# 1. Modify the sample code (DHT11_sample.py) to collect both temperature and humidity with timestamps of each measurement for more than 1 minute and save the data in a CSV file.
#   * Try to change temperature and humidity while collecting data to see if it works well (e.g., gently wrapping around the sensor with your hands may help).
#   * Headers of the CSV file should be ‘Timestamp’, ‘Temperature’, and ‘Humidity’.
#   * Hint: use ‘csv’, ‘time’ and ‘datetime’ packages and ‘while’ or ‘for’ loop.
#
#   * Note that the minimum refresh rate of DHT11 is 2 seconds. So, measurement period (sampling period) of your code should be more than 2 seconds (e.g., 3 seconds).
#
# 2. Copy and paste below the code that you developed for this Task.
#
# 3. Once the csv file is generated, save a copy of it in your laptop (You will need it for plotting)

# %%
#Copy + Paste your code below this line

# %% [markdown]
# Please continue to [Lab 2.2 here](L2_Colab2.ipynb).
