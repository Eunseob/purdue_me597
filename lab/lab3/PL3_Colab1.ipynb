# %% [markdown]
# # Prelab 4.1 IoT Sensor Data Collection 3 - Power meter (Modbus) and CNC controller (TCP/IP)

# %% [markdown]
# ## Learning Goals
#
# Students will be able to:
# 1.    Define and describe Modbus and TCP/IP protocols
# 2.    Define and describe electric power measurement principles
# 3.    Apply OEE to machine tools

# %% [markdown]
# ## 1.1 Introduction
#
#
# Seamless real-time communication is the core prerequisite for all Industry 4.0 and Industrial Internet of
# Things (IIoT) implementations. In Lab4, we will collect data from two IoT devices, a power meter (Acuvim L series
# (https://www.accuenergy.com/products/acuvim-l-multifunction-power-energy-meter/, available on Jan. 31,
# 2022), AccuEnergy, Canada), and a CNC machine tool controller (Haas controller
# (https://www.haascnc.com/productivity/control.html, available on Jan. 31, 2022), Haas, USA). Please visit and look into both web pages of the devices. For the power meter, Modbus protocol will be used. On the other hand, for the CNC controller, TCP/IP (so-called EtherNet/IP) protocol will be used. This prelab is to install a related package on Raspberry Pi and to be familiar with the devices. Modbus is a representative protocol in Fieldbus communications. And TCP/IP is a representative protocol in Industrial Ethernet communications.

# %% [markdown]
# ## 1.2 Python package installation on Raspberry Pi

# %% [markdown]
# ### 'pymodbus' package installation
#
# Install 'mymodbus' package on your Raspberry Pi as below.
#
# ---
# **Raspberry Pi - Terminal**
#
# `pip3 install pymodbus`
#
# ---
#
# After installing 'pymodbus' package, see if it is installed successfully using the command 'pip3 list'.

# %% [markdown]
# ### Task 1.1
#
# Capture your terminal window as Figure 1 after running 'pip3 list'.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/PL4_Figure1.png?raw=true)
#
# *Figure 1 Checking the installed Python packages*

# %% [markdown]
# ---
#
# Place your screenshot in here.
#
# ---

# %% [markdown]
# ###Task 1.2
#
# Address the following questions by checking provided resources.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('txi2p5_OjKU')

#Watch this video to answer question 1.

# %%
#@title 1) Explain what is Modbus protocol? {display-mode: "form"}
T1 = '' #@param {type:"string"}
print(T1)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('614QGgw_FA4')

#Watch this video to answer question 2.

# %%
#@title 2) Explain what is TCP/IP protocol? {display-mode: "form"}
T2 = '' #@param {type:"string"}
print(T2)

# %% [markdown]
# ###Refer to the following tutorial to answer questions 3 and 4:
# https://tmi.yokogawa.com/library/resources/training-modules/power-meter-tutorials-measurement/

# %%
#@title 3) What are the electric power meter and its applications? {display-mode: "form"}
T3 = '' #@param {type:"string"}
print(T3)

# %%
#@title 4) What are the principles of the electric power measurement? {display-mode: "form"}
T4 = '' #@param {type:"string"}
print(T4)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lEyNWtM6MW4')

#Watch this video to answer question 5.

# %%
#@title 5) What is CNC machine tool and how it works? {display-mode: "form"}
T5 = '' #@param {type:"string"}
print(T5)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('mXJU8OM593Y')

#Watch this video to answer question 6.

# %%
#@title 6) What is OEE (Overall Equipment Effectiveness)? {display-mode: "form"}
T6 = '' #@param {type:"string"}
print(T6)

# %%
#@title 7) To calculate a CNC machine tool’s OEE, which data do you need? {display-mode: "form"}
T7 = '' #@param {type:"string"}
print(T7)
